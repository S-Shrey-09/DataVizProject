# %%
#importing numpy for mathematical functions
import numpy as np

# %%
#importing pandas for data extraction and organisation
import pandas as pd

# %%
#importing GNI data csv
df = pd.read_csv('DataVizProject/Initial Data/GNIdata.csv')

# %%
#column check
print(df.columns)
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020'],
#       dtype='object')

# %%
#selecting specific columns 
cols = list(df.columns)
df1 = df[cols[0:1] + cols[43:64]]

# %%
print(df1.columns)
# Out:
# Index(['Country Name', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015', '2016', '2017', '2018', '2019'],
#       dtype='object')

# %%
#getting specific countries' data using regex. This method gives country's index without knowing exact name listed
import re
df1.loc[df1['Country Name'].str.contains('India|Bangladesh|South Africa|Algeria|Morocco|Egypt|Indonesia|World|Luxembourg|Australia|France|Brazil|China|Japan|United States|Mexico|Canada|Denmark|Norway|Peru|Argentina|Poland|Greece|New Zealand|Iran', flags=re.I, regex=True)]
# Out:
#              Country Name          1999          2000          2001  \
# 7              Arab World   2455.149369   2614.494074   2726.045211
# 9               Argentina   7580.000000   7470.000000   7000.000000
# 13              Australia  21440.000000  21130.000000  20160.000000
# 20             Bangladesh    420.000000    440.000000    440.000000
# 29                 Brazil   4120.000000   3930.000000   3350.000000
# 35                 Canada  21210.000000  22620.000000  23030.000000
# 40                  China    860.000000    940.000000   1010.000000
# 58                Denmark  33060.000000  32580.000000  31410.000000
# 60                Algeria   1530.000000   1590.000000   1670.000000
# 67       Egypt, Arab Rep.   1310.000000   1420.000000   1430.000000
# 77                 France  25420.000000  24970.000000  23840.000000
# 89                 Greece           NaN           NaN           NaN
# 96   Hong Kong SAR, China  25800.000000  26930.000000  26350.000000
# ...

# %%
#saving 25 selected counties using their index as df2
#choosing the following countries to increase economical diversity
df2 = df1.loc[[9,13,20,35,29,40,58,60,67,77,89,106,109,112,119,144,148,154,177,180,186,190,251,259,263]]

# %%
#resetting index for better accessiblity
df2 = df2.reset_index(drop=True)
df2
# Out:
#           Country Name          1999          2000          2001  \
# 0            Argentina   7580.000000   7470.000000   7000.000000
# 1            Australia  21440.000000  21130.000000  20160.000000
# 2           Bangladesh    420.000000    440.000000    440.000000
# 3               Canada  21210.000000  22620.000000  23030.000000
# 4               Brazil   4120.000000   3930.000000   3350.000000
# 5                China    860.000000    940.000000   1010.000000
# 6              Denmark  33060.000000  32580.000000  31410.000000
# 7              Algeria   1530.000000   1590.000000   1670.000000
# 8     Egypt, Arab Rep.   1310.000000   1420.000000   1430.000000
# 9               France  25420.000000  24970.000000  23840.000000
# 10              Greece           NaN           NaN           NaN
# 11           Indonesia    570.000000    580.000000    720.000000
# 12               India    440.000000    440.000000    450.000000
# ...

# %%
#EDA with .describe()
df2.describe()
# Out:
#                1999          2000          2001          2002          2003  \
# count     24.000000     24.000000     24.000000     24.000000     24.000000
# mean   12791.399328  13003.763429  12950.760080  12723.517459  13815.623581
# std    14545.917094  14801.644354  14843.826099  14663.826047  15936.321800
# min      420.000000    440.000000    440.000000    440.000000    460.000000
# 25%     1500.000000   1547.500000   1610.000000   1640.000000   1832.500000
# 50%     4886.791934   5095.161147   5104.120955   4470.000000   4575.000000
# 75%    22435.000000  23207.500000  23232.500000  23220.000000  25877.500000
# 14               Japan  34320.000000  36810.000000  37380.000000
# 9               France  25420.000000  24970.000000  23840.000000
# 19         New Zealand  15040.000000  14080.000000  13810.000000
# 10              Greece           NaN           NaN           NaN
# 21              Poland   4440.000000   4670.000000   4710.000000
# 0            Argentina   7580.000000   7470.000000   7000.000000
# 4               Brazil   4120.000000   3930.000000   3350.000000
# ...

# %%
df2.sort_values('2019', ascending=False)
# Out:
#           Country Name          1999          2000          2001  \
# 18              Norway  35540.000000  36540.000000  38220.000000
# 15          Luxembourg  46520.000000  45650.000000  44950.000000
# 22       United States  33670.000000  35960.000000  36720.000000
# 6              Denmark  33060.000000  32580.000000  31410.000000
# 1            Australia  21440.000000  21130.000000  20160.000000
# 3               Canada  21210.000000  22620.000000  23030.000000
# 19         New Zealand  15040.000000  14080.000000  13810.000000
# 9               France  25420.000000  24970.000000  23840.000000
# 14               Japan  34320.000000  36810.000000  37380.000000
# 10              Greece           NaN           NaN           NaN
# 21              Poland   4440.000000   4670.000000   4710.000000
# 23               World   5333.583867   5520.322295   5498.241909
# 0            Argentina   7580.000000   7470.000000   7000.000000
# ...

# %%
#EDA using info()
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 22 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Name  25 non-null     object
#  1   1999          24 non-null     float64
#  2   2000          24 non-null     float64
#  3   2001          24 non-null     float64
#  4   2002          24 non-null     float64
#  5   2003          24 non-null     float64
#  6   2004          24 non-null     float64
#  7   2005          24 non-null     float64
#  8   2006          25 non-null     float64
#  9   2007          25 non-null     float64
#  10  2008          25 non-null     float64
#  11  2009          25 non-null     float64
#  12  2010          25 non-null     float64
#  13  2011          25 non-null     float64
#  14  2012          25 non-null     float64
#  15  2013          25 non-null     float64
#  16  2014          25 non-null     float64
# ...

# %%
#EDA using correlation .corr()
df2.corr()
# Out:
#           1999      2000      2001      2002      2003      2004      2005  \
# 1999  1.000000  0.998515  0.995966  0.991300  0.990113  0.990863  0.985826
# 2000  0.998515  1.000000  0.999123  0.995421  0.992571  0.988611  0.981319
# 2001  0.995966  0.999123  1.000000  0.997786  0.994677  0.988798  0.980797
# 2002  0.991300  0.995421  0.997786  1.000000  0.998614  0.991030  0.983247
# 2003  0.990113  0.992571  0.994677  0.998614  1.000000  0.994802  0.988995
# 2004  0.990863  0.988611  0.988798  0.991030  0.994802  1.000000  0.998473
# 2005  0.985826  0.981319  0.980797  0.983247  0.988995  0.998473  1.000000
# 2006  0.979600  0.975412  0.975327  0.980366  0.987706  0.994965  0.997731
# 2007  0.968962  0.962235  0.961758  0.965884  0.974467  0.989181  0.995274
# 2008  0.959571  0.952667  0.952463  0.958566  0.968544  0.982243  0.989861
# 2009  0.949739  0.944476  0.945102  0.954777  0.965822  0.972392  0.979374
# ...

# %%
#importing matplotlib for checking outliers
import matplotlib.pyplot as plt

# %%
#importing seaborn for swarm plot
import seaborn as sb
sb.set_theme(style="whitegrid")

# plotting swarm plot 
df3 = df2.sort_values('1999', ascending=False)
sb.swarmplot(x= "1999", y = "Country Name",data= df3)

# display
plt.show()

# %%
#saving new 25x22 dataset of GNI of chosen countries
df2.to_csv('GNIdataPlot.csv')
